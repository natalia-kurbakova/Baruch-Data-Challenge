# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('train_updated.csv')
df = df.dropna()

# %%
df.describe()
# Out:
#            deviceid  avg_time_charging_lag1  avg_time_charging_lag2  \
# count  33832.000000            33832.000000             33832.00000
# mean   27523.530415               16.182491                16.54314
# std    12966.496729               15.334782                15.43497
# min     5000.000000                1.510000                 1.06000
# 25%    16294.750000                4.910000                 4.92000
# 50%    27504.500000                5.770000                 5.83000
# 75%    38774.250000               29.770000                30.79000
# max    49998.000000               82.550000                98.89000
#
#        avg_time_charging_lag3  avg_time_charging_lag7  charging_rate_lag3  \
# count            33832.000000            33832.000000        33832.000000
# mean                16.267959               16.344610           -0.042742
# std                 15.305808               15.196508            0.797105
# min                  0.040000                1.070000          -76.946667
# 25%                  4.910000                4.900000           -0.063333
# 50%                  5.780000                5.780000            0.000000
# 75%                 30.010000               29.700000            0.046667
# max                 81.000000               81.890000            9.556667
#
#        charging_rate_lag7  avg_time_discharging_lag1  \
# count        33832.000000               33832.000000
# mean            -0.052521                  25.610492
# std              0.759198                  29.138369
# min            -42.130000                   0.520000
# 25%             -0.100000                   4.200000
# 50%             -0.003333                   5.860000
# 75%              0.060000                  49.662500
# max             17.913333                 104.060000
#
#        avg_time_discharging_lag2  avg_time_discharging_lag3  ...  \
# count               33832.000000               33832.000000  ...
# mean                   26.391300                  25.856262  ...
# std                    29.464778                  29.236861  ...
# min                     0.700000                   1.070000  ...
# 25%                     4.210000                   4.200000  ...
# 50%                     5.920000                   5.850000  ...
# 75%                    51.330000                  50.142500  ...
# max                   110.560000                 108.170000  ...
#
#        dischargecycles  total_off_time  number_times_restart  \
# count     33832.000000     33832.00000          33832.000000
# mean         84.833228        25.23022              2.153646
# std          14.817297        34.50949              2.125769
# min          21.062500         0.00000              0.294118
# 25%          74.850000         4.40000              1.066667
# 50%          84.811012        17.87500              1.500000
# 75%          94.739130        37.00000              2.375000
# max         145.333333      2013.00000             34.933333
#
#        avg_volt_change_charging  avg_volt_change_discharging  \
# count              33832.000000                 33832.000000
# mean                 351.412834                   348.205980
# std                   12.142624                    12.632874
# min                  306.169000                   302.499048
# 25%                  343.071682                   339.657667
# 50%                  351.126905                   347.891278
# 75%                  359.403437                   356.521094
# max                  405.446111                   403.850000
#
#        avg_time_charging  avg_time_discharging  max_voltage_day    piececount  \
# count       33832.000000          33832.000000     33832.000000  33832.000000
# mean           16.354944             26.083136      4159.255202     20.577940
# std             3.385811              6.484972        10.783707     15.987928
# min             5.522667              5.570667      4114.466667      1.000000
# 25%            14.021681             21.606456      4151.940257     11.571429
# 50%            16.221378             25.809028      4159.133333     16.727273
# 75%            18.579420             30.316052      4166.500000     24.333333
# max            30.937059             55.925789      4206.235294    418.916667
#
#          cycle_time
# count  33832.000000
# mean      42.438081
# std        9.826729
# min       11.093333
# 25%       35.682283
# 50%       42.036583
# 75%       48.875312
# max       86.853158
#
# [8 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['deviceid', 'avg_time_charging_lag1', 'avg_time_charging_lag2',
#        'avg_time_charging_lag3', 'avg_time_charging_lag7',
#        'charging_rate_lag3', 'charging_rate_lag7', 'avg_time_discharging_lag1',
#        'avg_time_discharging_lag2', 'avg_time_discharging_lag3',
#        'avg_time_discharging_lag7', 'discharging_rate_lag3',
#        'discharging_rate_lag7', 'fail_7', 'charge_cycle_time_below_12',
#        'avg_time_charging_lag4', 'avg_time_discharging_lag4',
#        'avg_time_charging_lag5', 'avg_time_discharging_lag5',
#        'avg_time_charging_lag6', 'avg_time_discharging_lag6',
#        'avg_time_charging_lag8', 'avg_time_discharging_lag8',
#        'avg_time_charging_lag9', 'avg_time_discharging_lag9',
#        'avg_time_charging_lag10', 'avg_time_discharging_lag10',
#        'avg_time_charging_lag11', 'avg_time_discharging_lag11',
#        'avg_time_charging_lag12', 'avg_time_discharging_lag12',
#        'avg_time_charging_lag13', 'avg_time_discharging_lag13',
#        'avg_time_charging_lag14', 'avg_time_discharging_lag14',
#        'discharging_rate_lag4', 'discharging_rate_lag5',
#        'discharging_rate_lag6', 'discharging_rate_lag8', 'charging_rate_lag4',
#        'charging_rate_lag5', 'charging_rate_lag6', 'chargecycles',
#        'dischargecycles', 'total_off_time', 'number_times_restart',
#        'avg_volt_change_charging', 'avg_volt_change_discharging',
#        'avg_time_charging', 'avg_time_discharging', 'max_voltage_day',
#        'piececount', 'cycle_time', 'LastRecord', 'Date Deployed'],
#       dtype='object')

# %%
#from lag columns we calculate only: AVG_charging_rate and AVG_discharging_rate

# %%
ser_charging_rate = df[['charging_rate_lag3', 'charging_rate_lag4', 'charging_rate_lag5',
       'charging_rate_lag6', 'charging_rate_lag7']].mean(axis=1)
ser_discharging_rate = df[['discharging_rate_lag3',
       'discharging_rate_lag4', 'discharging_rate_lag5',
       'discharging_rate_lag6', 'discharging_rate_lag7',
       'discharging_rate_lag8']].mean(axis=1)

# %%
newdf = df[['deviceid', 'chargecycles', 'dischargecycles', 'total_off_time',
       'number_times_restart', 'avg_volt_change_charging',
       'avg_volt_change_discharging', 'avg_time_charging',
       'avg_time_discharging', 'max_voltage_day', 'piececount', 'cycle_time', 'Date Deployed', 'charge_cycle_time_below_12', 'fail_7']]

# %%
newdf['AVG_charging_rate'] = ser_charging_rate
newdf['AVG_discharging_rate'] = ser_discharging_rate
# Out:
# /var/folders/8b/n43vy0qj04d0hdqjf03h96bm0000gn/T/ipykernel_9200/280979940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['AVG_charging_rate'] = ser_charging_rate
# /var/folders/8b/n43vy0qj04d0hdqjf03h96bm0000gn/T/ipykernel_9200/280979940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['AVG_discharging_rate'] = ser_discharging_rate

# %%
newdf
# Out:
#        deviceid  chargecycles  dischargecycles  total_off_time  \
# 2         16107     80.380952        80.333333        2.333333
# 3         27362     91.736842        91.684211       10.789474
# 4         19463     71.066667        70.733333       14.266667
# 5         30054    100.900000       100.550000       10.700000
# 6         26431     72.130435        71.869565       60.304348
# ...         ...           ...              ...             ...
# 40495     16284     83.434783        82.956522       17.739130
# 40496     49732     64.866667        64.733333        0.266667
# 40497     43158     84.727273        84.590909        6.727273
# 40498      5860     94.100000        94.000000       24.050000
# 40499     20795     76.181818        76.045455        9.636364
#
#        number_times_restart  avg_volt_change_charging  \
# 2                  4.095238                346.113333
# 3                  0.736842                356.184211
# 4                  1.133333                370.904000
# 5                  2.150000                350.345500
# 6                  1.956522                358.789130
# ...                     ...                       ...
# 40495              2.782609                365.399130
# 40496              1.066667                378.554667
# 40497              2.227273                345.429091
# 40498              6.750000                364.964000
# 40499              6.045455                345.897727
#
#        avg_volt_change_discharging  avg_time_charging  avg_time_discharging  \
# 2                       343.409524          13.675238             20.471429
# 3                       349.844737          16.306842             26.189474
# 4                       367.730000          18.797333             30.812000
# 5                       346.747500          12.878500             19.621000
# 6                       353.025652          17.384783             27.495217
# ...                            ...                ...                   ...
# 40495                   354.915217          13.880435             23.077391
# 40496                   374.952667          17.673333             28.495333
# 40497                   342.216818          17.871818             29.766364
# 40498                   362.155500          14.557000             22.894000
# 40499                   337.337727          21.834091             34.135000
#
#        max_voltage_day  piececount  cycle_time Date Deployed  \
# 2          4152.238095   19.200000   34.146667    10/31/2019
# 3          4164.631579   23.625000   42.496316     10/1/2019
# 4          4169.800000   12.666667   49.609333     9/13/2019
# 5          4151.600000    6.375000   32.499500     10/5/2019
# 6          4170.652174   20.500000   44.880000     9/13/2019
# ...                ...         ...         ...           ...
# 40495      4162.913043   70.181818   36.957826      9/5/2019
# 40496      4181.600000   11.888889   46.168667     9/18/2019
# 40497      4157.045455   26.400000   47.638182    10/18/2019
# 40498      4171.650000   17.714286   37.451000     10/2/2019
# 40499      4155.045455   30.857143   55.969091     9/16/2019
#
#        charge_cycle_time_below_12  fail_7  AVG_charging_rate  \
# 2                           False       0          -0.116667
# 3                           False       0           0.368000
# 4                            True       0           0.304667
# 5                           False       0           0.163333
# 6                           False       0           1.252000
# ...                           ...     ...                ...
# 40495                        True       1          -0.037333
# 40496                        True       1          -0.202000
# 40497                        True       1           0.347333
# 40498                        True       0           0.115333
# 40499                        True       1           0.300000
#
#        AVG_discharging_rate
# 2                 -0.258333
# 3                 -0.008889
# 4                 -0.355000
# 5                  0.147778
# 6                  0.565556
# ...                     ...
# 40495              0.215556
# 40496              0.063333
# 40497             -0.678889
# 40498              0.011111
# 40499              0.017222
#
# [33832 rows x 17 columns]

# %%
newdf.corr()
# Out:
#                              deviceid  chargecycles  dischargecycles  \
# deviceid                     1.000000      0.005005         0.004893
# chargecycles                 0.005005      1.000000         0.999941
# dischargecycles              0.004893      0.999941         1.000000
# total_off_time               0.002866     -0.068357        -0.068078
# number_times_restart         0.001392     -0.004639        -0.005016
# avg_volt_change_charging     0.004949      0.088241         0.088125
# avg_volt_change_discharging  0.003637      0.146892         0.148347
# avg_time_charging           -0.002856     -0.811278        -0.811406
# avg_time_discharging        -0.002257     -0.808570        -0.808783
# max_voltage_day              0.004074      0.153913         0.153742
# piececount                   0.000176     -0.016899        -0.016973
# cycle_time                  -0.002473     -0.813128        -0.813313
# charge_cycle_time_below_12   0.002419      0.194543         0.194572
# fail_7                      -0.000754      0.060038         0.060003
# AVG_charging_rate           -0.002609      0.003275         0.003267
# AVG_discharging_rate         0.000433      0.013802         0.013681
#
#                              total_off_time  number_times_restart  \
# deviceid                           0.002866              0.001392
# chargecycles                      -0.068357             -0.004639
# dischargecycles                   -0.068078             -0.005016
# total_off_time                     1.000000              0.137942
# number_times_restart               0.137942              1.000000
# avg_volt_change_charging           0.110750              0.100430
# avg_volt_change_discharging        0.106743              0.093005
# avg_time_charging                 -0.042589             -0.060088
# avg_time_discharging              -0.033430             -0.050611
# max_voltage_day                    0.088568              0.100906
# piececount                         0.001384              0.003241
# cycle_time                        -0.036736             -0.054103
# charge_cycle_time_below_12        -0.005123              0.004130
# fail_7                             0.007333              0.023273
# AVG_charging_rate                 -0.013368              0.002982
# AVG_discharging_rate              -0.015253              0.005544
#
#                              avg_volt_change_charging  \
# deviceid                                     0.004949
# chargecycles                                 0.088241
# dischargecycles                              0.088125
# total_off_time                               0.110750
# number_times_restart                         0.100430
# avg_volt_change_charging                     1.000000
# avg_volt_change_discharging                  0.971350
# avg_time_charging                           -0.327475
# avg_time_discharging                        -0.309881
# max_voltage_day                              0.905568
# piececount                                   0.009026
# cycle_time                                  -0.317332
# charge_cycle_time_below_12                   0.054980
# fail_7                                       0.124378
# AVG_charging_rate                            0.009738
# AVG_discharging_rate                         0.054693
#
#                              avg_volt_change_discharging  avg_time_charging  \
# deviceid                                        0.003637          -0.002856
# chargecycles                                    0.146892          -0.811278
# dischargecycles                                 0.148347          -0.811406
# total_off_time                                  0.106743          -0.042589
# number_times_restart                            0.093005          -0.060088
# avg_volt_change_charging                        0.971350          -0.327475
# avg_volt_change_discharging                     1.000000          -0.379382
# avg_time_charging                              -0.379382           1.000000
# avg_time_discharging                           -0.364570           0.980239
# max_voltage_day                                 0.885485          -0.392610
# piececount                                      0.007810           0.010451
# cycle_time                                     -0.371308           0.991442
# charge_cycle_time_below_12                      0.066336          -0.178305
# fail_7                                          0.122882          -0.055764
# AVG_charging_rate                               0.009109           0.024504
# AVG_discharging_rate                            0.054681          -0.023449
#
#                              avg_time_discharging  max_voltage_day  \
# deviceid                                -0.002257         0.004074
# chargecycles                            -0.808570         0.153913
# dischargecycles                         -0.808783         0.153742
# total_off_time                          -0.033430         0.088568
# number_times_restart                    -0.050611         0.100906
# avg_volt_change_charging                -0.309881         0.905568
# avg_volt_change_discharging             -0.364570         0.885485
# avg_time_charging                        0.980239        -0.392610
# avg_time_discharging                     1.000000        -0.384866
# max_voltage_day                         -0.384866         1.000000
# piececount                               0.006013         0.022635
# cycle_time                               0.997675        -0.389260
# charge_cycle_time_below_12              -0.176457         0.059568
# fail_7                                  -0.053006         0.105162
# AVG_charging_rate                        0.003982         0.002114
# AVG_discharging_rate                     0.008073         0.038782
#
#                              piececount  cycle_time  \
# deviceid                       0.000176   -0.002473
# chargecycles                  -0.016899   -0.813128
# dischargecycles               -0.016973   -0.813313
# total_off_time                 0.001384   -0.036736
# number_times_restart           0.003241   -0.054103
# avg_volt_change_charging       0.009026   -0.317332
# avg_volt_change_discharging    0.007810   -0.371308
# avg_time_charging              0.010451    0.991442
# avg_time_discharging           0.006013    0.997675
# max_voltage_day                0.022635   -0.389260
# piececount                     1.000000    0.007569
# cycle_time                     0.007569    1.000000
# charge_cycle_time_below_12     0.011665   -0.177885
# fail_7                         0.008446   -0.054194
# AVG_charging_rate             -0.008765    0.011070
# AVG_discharging_rate          -0.019169   -0.002752
#
#                              charge_cycle_time_below_12    fail_7  \
# deviceid                                       0.002419 -0.000754
# chargecycles                                   0.194543  0.060038
# dischargecycles                                0.194572  0.060003
# total_off_time                                -0.005123  0.007333
# number_times_restart                           0.004130  0.023273
# avg_volt_change_charging                       0.054980  0.124378
# avg_volt_change_discharging                    0.066336  0.122882
# avg_time_charging                             -0.178305 -0.055764
# avg_time_discharging                          -0.176457 -0.053006
# max_voltage_day                                0.059568  0.105162
# piececount                                     0.011665  0.008446
# cycle_time                                    -0.177885 -0.054194
# charge_cycle_time_below_12                     1.000000  0.294690
# fail_7                                         0.294690  1.000000
# AVG_charging_rate                              0.009375  0.012055
# AVG_discharging_rate                           0.013084  0.020606
#
#                              AVG_charging_rate  AVG_discharging_rate
# deviceid                             -0.002609              0.000433
# chargecycles                          0.003275              0.013802
# dischargecycles                       0.003267              0.013681
# total_off_time                       -0.013368             -0.015253
# number_times_restart                  0.002982              0.005544
# avg_volt_change_charging              0.009738              0.054693
# avg_volt_change_discharging           0.009109              0.054681
# avg_time_charging                     0.024504             -0.023449
# avg_time_discharging                  0.003982              0.008073
# max_voltage_day                       0.002114              0.038782
# piececount                           -0.008765             -0.019169
# cycle_time                            0.011070             -0.002752
# charge_cycle_time_below_12            0.009375              0.013084
# fail_7                                0.012055              0.020606
# AVG_charging_rate                     1.000000              0.262842
# AVG_discharging_rate                  0.262842              1.000000
