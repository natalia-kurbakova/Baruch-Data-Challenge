# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia-kurbakova/Baruch-Data-Challenge/blob/main/Full_Version2_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

from sklearn.cluster import KMeans
import xgboost as xgb

train = pd.read_csv('train_updated.csv')
train = pd.DataFrame(train)
train.set_index('deviceid')

#pd.set_option('display.max_columns', 10)
#pd.set_option('display.max_rows', 10)

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40500 entries, 0 to 40499
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   deviceid                     40500 non-null  int64
#  1   avg_time_charging_lag1       40500 non-null  float64
#  2   avg_time_charging_lag2       40500 non-null  float64
#  3   avg_time_charging_lag3       40500 non-null  float64
#  4   avg_time_charging_lag7       40434 non-null  float64
#  5   charging_rate_lag3           40500 non-null  float64
#  6   charging_rate_lag7           40488 non-null  float64
#  7   avg_time_discharging_lag1    40500 non-null  float64
#  8   avg_time_discharging_lag2    40500 non-null  float64
#  9   avg_time_discharging_lag3    40500 non-null  float64
#  10  avg_time_discharging_lag7    40434 non-null  float64
#  11  discharging_rate_lag3        40500 non-null  float64
#  12  discharging_rate_lag7        40488 non-null  float64
#  13  fail_7                       40500 non-null  int64
#  14  charge_cycle_time_below_12   40500 non-null  bool
#  15  avg_time_charging_lag4       40500 non-null  float64
#  16  avg_time_discharging_lag4    40500 non-null  float64
#  17  avg_time_charging_lag5       40493 non-null  float64
#  18  avg_time_discharging_lag5    40493 non-null  float64
#  19  avg_time_charging_lag6       40472 non-null  float64
#  20  avg_time_discharging_lag6    40472 non-null  float64
#  21  avg_time_charging_lag8       40338 non-null  float64
#  22  avg_time_discharging_lag8    40338 non-null  float64
#  23  avg_time_charging_lag9       40126 non-null  float64
#  24  avg_time_discharging_lag9    40126 non-null  float64
#  25  avg_time_charging_lag10      39703 non-null  float64
#  26  avg_time_discharging_lag10   39703 non-null  float64
#  27  avg_time_charging_lag11      38914 non-null  float64
#  28  avg_time_discharging_lag11   38914 non-null  float64
#  29  avg_time_charging_lag12      37743 non-null  float64
#  30  avg_time_discharging_lag12   37743 non-null  float64
#  31  avg_time_charging_lag13      36118 non-null  float64
#  32  avg_time_discharging_lag13   36118 non-null  float64
#  33  avg_time_charging_lag14      33832 non-null  float64
#  34  avg_time_discharging_lag14   33832 non-null  float64
#  35  discharging_rate_lag4        40500 non-null  float64
#  36  discharging_rate_lag5        40500 non-null  float64
#  37  discharging_rate_lag6        40498 non-null  float64
#  38  discharging_rate_lag8        40469 non-null  float64
#  39  charging_rate_lag4           40500 non-null  float64
#  40  charging_rate_lag5           40500 non-null  float64
#  41  charging_rate_lag6           40498 non-null  float64
#  42  chargecycles                 40500 non-null  float64
#  43  dischargecycles              40500 non-null  float64
#  44  total_off_time               40500 non-null  float64
#  45  number_times_restart         40500 non-null  float64
#  46  avg_volt_change_charging     40500 non-null  float64
#  47  avg_volt_change_discharging  40500 non-null  float64
#  48  avg_time_charging            40500 non-null  float64
#  49  avg_time_discharging         40500 non-null  float64
#  50  max_voltage_day              40500 non-null  float64
#  51  piececount                   40500 non-null  float64
#  52  cycle_time                   40500 non-null  float64
#  53  LastRecord                   40500 non-null  object
#  54  Date Deployed                40500 non-null  object
# dtypes: bool(1), float64(50), int64(2), object(2)
# memory usage: 16.7+ MB

# %%
train.head()
# Out:
#    deviceid  avg_time_charging_lag1  avg_time_charging_lag2  \
# 0     28647                    5.12                   41.11
# 1     36175                   36.60                    5.16
# 2     16107                    5.51                    5.04
# 3     27362                    4.66                   39.85
# 4     19463                    5.10                   43.24
#
#    avg_time_charging_lag3  avg_time_charging_lag7  charging_rate_lag3  \
# 0                    6.56                   25.39            0.086667
# 1                    6.23                    6.96            0.136667
# 2                    4.52                    5.96           -0.460000
# 3                   35.76                   40.69            0.076667
# 4                    4.63                    5.26            0.040000
#
#    charging_rate_lag7  avg_time_discharging_lag1  avg_time_discharging_lag2  \
# 0           -0.006667                       4.37                      91.70
# 1           -1.296667                      62.67                       6.53
# 2           -0.083333                       5.13                       5.65
# 3           -0.006667                       3.93                      76.37
# 4           -0.153333                       4.69                      71.44
#
#    avg_time_discharging_lag3  ...  number_times_restart  \
# 0                      15.70  ...              2.375000
# 1                       6.16  ...              1.000000
# 2                       4.14  ...              4.095238
# 3                      60.86  ...              0.736842
# 4                       3.80  ...              1.133333
#
#    avg_volt_change_charging  avg_volt_change_discharging  avg_time_charging  \
# 0                377.080000                   367.428750          21.696250
# 1                350.517857                   350.309286          19.883571
# 2                346.113333                   343.409524          13.675238
# 3                356.184211                   349.844737          16.306842
# 4                370.904000                   367.730000          18.797333
#
#    avg_time_discharging  max_voltage_day  piececount  cycle_time  LastRecord  \
# 0             39.005000      4174.875000   14.200000   60.701250      4/1/21
# 1             32.213571      4161.000000   19.777778   52.097143      4/1/21
# 2             20.471429      4152.238095   19.200000   34.146667      4/1/21
# 3             26.189474      4164.631579   23.625000   42.496316      4/1/21
# 4             30.812000      4169.800000   12.666667   49.609333      4/1/21
#
#    Date Deployed
# 0        10/6/19
# 1       10/27/19
# 2       10/31/19
# 3        10/1/19
# 4        9/13/19
#
# [5 rows x 55 columns]

# %%
#trainlag is df with lag columns
trainlag = train[['avg_time_charging_lag1', 'avg_time_charging_lag2', 'avg_time_charging_lag3', 'avg_time_charging_lag4', 
            'avg_time_charging_lag5', 'avg_time_charging_lag6', 'avg_time_charging_lag7', 'avg_time_charging_lag8', 
            'avg_time_charging_lag9', 'avg_time_charging_lag10', 'avg_time_charging_lag11', 'avg_time_charging_lag12', 
            'avg_time_charging_lag13', 'avg_time_charging_lag14',

            'avg_time_discharging_lag1', 'avg_time_discharging_lag2', 'avg_time_discharging_lag3', 'avg_time_discharging_lag4',
            'avg_time_discharging_lag5', 'avg_time_discharging_lag6', 'avg_time_discharging_lag7', 'avg_time_discharging_lag8',
            'avg_time_discharging_lag9', 'avg_time_discharging_lag10', 'avg_time_discharging_lag11', 'avg_time_discharging_lag12', 
            'avg_time_discharging_lag13', 'avg_time_discharging_lag14',

            'charging_rate_lag3', 'charging_rate_lag4', 'charging_rate_lag5', 'charging_rate_lag6', 'charging_rate_lag7',

            'discharging_rate_lag3', 'discharging_rate_lag4', 'discharging_rate_lag5', 'discharging_rate_lag6', 
            'discharging_rate_lag7', 'discharging_rate_lag8']].copy()

# %%
trainlag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40500 entries, 0 to 40499
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   avg_time_charging_lag1      40500 non-null  float64
#  1   avg_time_charging_lag2      40500 non-null  float64
#  2   avg_time_charging_lag3      40500 non-null  float64
#  3   avg_time_charging_lag4      40500 non-null  float64
#  4   avg_time_charging_lag5      40493 non-null  float64
#  5   avg_time_charging_lag6      40472 non-null  float64
#  6   avg_time_charging_lag7      40434 non-null  float64
#  7   avg_time_charging_lag8      40338 non-null  float64
#  8   avg_time_charging_lag9      40126 non-null  float64
#  9   avg_time_charging_lag10     39703 non-null  float64
#  10  avg_time_charging_lag11     38914 non-null  float64
#  11  avg_time_charging_lag12     37743 non-null  float64
#  12  avg_time_charging_lag13     36118 non-null  float64
#  13  avg_time_charging_lag14     33832 non-null  float64
#  14  avg_time_discharging_lag1   40500 non-null  float64
#  15  avg_time_discharging_lag2   40500 non-null  float64
#  16  avg_time_discharging_lag3   40500 non-null  float64
#  17  avg_time_discharging_lag4   40500 non-null  float64
#  18  avg_time_discharging_lag5   40493 non-null  float64
#  19  avg_time_discharging_lag6   40472 non-null  float64
#  20  avg_time_discharging_lag7   40434 non-null  float64
#  21  avg_time_discharging_lag8   40338 non-null  float64
#  22  avg_time_discharging_lag9   40126 non-null  float64
#  23  avg_time_discharging_lag10  39703 non-null  float64
#  24  avg_time_discharging_lag11  38914 non-null  float64
#  25  avg_time_discharging_lag12  37743 non-null  float64
#  26  avg_time_discharging_lag13  36118 non-null  float64
#  27  avg_time_discharging_lag14  33832 non-null  float64
#  28  charging_rate_lag3          40500 non-null  float64
#  29  charging_rate_lag4          40500 non-null  float64
#  30  charging_rate_lag5          40500 non-null  float64
#  31  charging_rate_lag6          40498 non-null  float64
#  32  charging_rate_lag7          40488 non-null  float64
#  33  discharging_rate_lag3       40500 non-null  float64
#  34  discharging_rate_lag4       40500 non-null  float64
#  35  discharging_rate_lag5       40500 non-null  float64
#  36  discharging_rate_lag6       40498 non-null  float64
#  37  discharging_rate_lag7       40488 non-null  float64
#  38  discharging_rate_lag8       40469 non-null  float64
# dtypes: float64(39)
# memory usage: 12.1 MB

# %%
trainlag.boxplot(figsize=(30,15.5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#df2 is df without lag columns
train2 = train[['deviceid','chargecycles', 'dischargecycles', 'total_off_time',
       'number_times_restart', 'avg_volt_change_charging',
       'avg_volt_change_discharging', 'avg_time_charging',
       'avg_time_discharging', 'max_voltage_day', 'piececount', 'cycle_time', 'Date Deployed', 
          'charge_cycle_time_below_12', 'fail_7']]
train2 = train2.set_index('deviceid')

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40500 entries, 28647 to 20795
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   chargecycles                 40500 non-null  float64
#  1   dischargecycles              40500 non-null  float64
#  2   total_off_time               40500 non-null  float64
#  3   number_times_restart         40500 non-null  float64
#  4   avg_volt_change_charging     40500 non-null  float64
#  5   avg_volt_change_discharging  40500 non-null  float64
#  6   avg_time_charging            40500 non-null  float64
#  7   avg_time_discharging         40500 non-null  float64
#  8   max_voltage_day              40500 non-null  float64
#  9   piececount                   40500 non-null  float64
#  10  cycle_time                   40500 non-null  float64
#  11  Date Deployed                40500 non-null  object
#  12  charge_cycle_time_below_12   40500 non-null  bool
#  13  fail_7                       40500 non-null  int64
# dtypes: bool(1), float64(11), int64(1), object(1)
# memory usage: 4.4+ MB

# %%
train2
# Out:
#           chargecycles  dischargecycles  total_off_time  number_times_restart  \
# deviceid
# 28647        50.250000        49.750000       49.000000              2.375000
# 36175        56.285714        56.000000       36.857143              1.000000
# 16107        80.380952        80.333333        2.333333              4.095238
# 27362        91.736842        91.684211       10.789474              0.736842
# 19463        71.066667        70.733333       14.266667              1.133333
# ...                ...              ...             ...                   ...
# 16284        83.434783        82.956522       17.739130              2.782609
# 49732        64.866667        64.733333        0.266667              1.066667
# 43158        84.727273        84.590909        6.727273              2.227273
# 5860         94.100000        94.000000       24.050000              6.750000
# 20795        76.181818        76.045455        9.636364              6.045455
#
#           avg_volt_change_charging  avg_volt_change_discharging  \
# deviceid
# 28647                   377.080000                   367.428750
# 36175                   350.517857                   350.309286
# 16107                   346.113333                   343.409524
# 27362                   356.184211                   349.844737
# 19463                   370.904000                   367.730000
# ...                            ...                          ...
# 16284                   365.399130                   354.915217
# 49732                   378.554667                   374.952667
# 43158                   345.429091                   342.216818
# 5860                    364.964000                   362.155500
# 20795                   345.897727                   337.337727
#
#           avg_time_charging  avg_time_discharging  max_voltage_day  \
# deviceid
# 28647             21.696250             39.005000      4174.875000
# 36175             19.883571             32.213571      4161.000000
# 16107             13.675238             20.471429      4152.238095
# 27362             16.306842             26.189474      4164.631579
# 19463             18.797333             30.812000      4169.800000
# ...                     ...                   ...              ...
# 16284             13.880435             23.077391      4162.913043
# 49732             17.673333             28.495333      4181.600000
# 43158             17.871818             29.766364      4157.045455
# 5860              14.557000             22.894000      4171.650000
# 20795             21.834091             34.135000      4155.045455
#
#           piececount  cycle_time Date Deployed  charge_cycle_time_below_12  \
# deviceid
# 28647      14.200000   60.701250       10/6/19                       False
# 36175      19.777778   52.097143      10/27/19                       False
# 16107      19.200000   34.146667      10/31/19                       False
# 27362      23.625000   42.496316       10/1/19                       False
# 19463      12.666667   49.609333       9/13/19                        True
# ...              ...         ...           ...                         ...
# 16284      70.181818   36.957826        9/5/19                        True
# 49732      11.888889   46.168667       9/18/19                        True
# 43158      26.400000   47.638182      10/18/19                        True
# 5860       17.714286   37.451000       10/2/19                        True
# 20795      30.857143   55.969091       9/16/19                        True
#
#           fail_7
# deviceid
# 28647          0
# 36175          0
# 16107          0
# 27362          0
# 19463          0
# ...          ...
# 16284          1
# 49732          1
# 43158          1
# 5860           0
# 20795          1
#
# [40500 rows x 14 columns]

# %%
train2.drop(columns=["fail_7", "max_voltage_day"]).boxplot(figsize=(30,15.5))
plt.show()

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40500 entries, 28647 to 20795
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   chargecycles                 40500 non-null  float64
#  1   dischargecycles              40500 non-null  float64
#  2   total_off_time               40500 non-null  float64
#  3   number_times_restart         40500 non-null  float64
#  4   avg_volt_change_charging     40500 non-null  float64
#  5   avg_volt_change_discharging  40500 non-null  float64
#  6   avg_time_charging            40500 non-null  float64
#  7   avg_time_discharging         40500 non-null  float64
#  8   max_voltage_day              40500 non-null  float64
#  9   piececount                   40500 non-null  float64
#  10  cycle_time                   40500 non-null  float64
#  11  Date Deployed                40500 non-null  object
#  12  charge_cycle_time_below_12   40500 non-null  bool
#  13  fail_7                       40500 non-null  int64
# dtypes: bool(1), float64(11), int64(1), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# #### Split the data by response, fail_7

# %%
fail = train2[train2.fail_7 == 1].copy()
nofail = train2[train2.fail_7 == 0].copy()

# %%
index = train2.select_dtypes(include=["float","int"]).columns
index = index.drop('total_off_time')
cols=[i for i in index]

fig, axes = plt.subplots(len(cols)//3, 3, figsize=(20, 48))

i = 0
for triaxis in axes:
    for axis in triaxis:
        fail.hist(column = cols[i], bins = 100, ax=axis, color = 'orange', alpha = 0.3)
        nofail.hist(column = cols[i], bins = 100, ax=axis, color = 'green', alpha = 0.3)
        i = i+1

# %%
nofail.drop(columns=["fail_7", "max_voltage_day"]).boxplot(figsize=(30,15.5))
plt.show()

# %%
fail.drop(columns=["fail_7", "max_voltage_day"]).boxplot(figsize=(30,15.5))
plt.show()

# %% [markdown]
# #### Analysis of (only) boolean predictor 'charge_cycle_time_below_12':
# ##### normal charge cycles is 12, bool variable is flag set for when that doesnt happen

# %%
fail['charge_cycle_time_below_12'].value_counts(normalize=True)

#6993/failed.shape[0] = 85% of devices that failed had charge cycle time below 12
# Out:
# True     0.849378
# False    0.150622
# Name: charge_cycle_time_below_12, dtype: float64

# %%
nofail['charge_cycle_time_below_12'].value_counts(normalize=True)
# Out:
# True     0.512364
# False    0.487636
# Name: charge_cycle_time_below_12, dtype: float64

# %%
#bool col CCTB12 True is when total charges cyles time less than 12 units (which is normal)

norm_charge_false_mask = train['charge_cycle_time_below_12'] == False
norm_charge_true_mask = train['charge_cycle_time_below_12'] == True

# %%
train[norm_charge_false_mask].fail_7.value_counts(normalize = True)
#of the devices that have normal charge cycles, 8.5% fail
# Out:
# 0    0.914601
# 1    0.085399
# Name: fail_7, dtype: float64

# %%
train[norm_charge_true_mask].fail_7.value_counts(normalize = True)
#of the devices that do not have normal charge cycles, 33% fail
# Out:
# 0    0.666165
# 1    0.333835
# Name: fail_7, dtype: float64

# %% [raw]
# We believe that this predictor ('charge_cycle_time_below_12') has a strong relationship with the response.

# %% [markdown]
# #### Analysis of total off time

# %%
tot_0_mask = train['total_off_time'] == 0 
tot_0 = train[tot_0_mask]
tot_0.fail_7.value_counts(normalize=True)

#When total off time is 0, 13% of devices fail
# Out:
# 0    0.861761
# 1    0.138239
# Name: fail_7, dtype: float64

# %%
train2.total_off_time.describe()
# Out:
# count    40500.000000
# mean        25.258990
# std         37.037053
# min          0.000000
# 25%          3.565217
# 50%         17.097619
# 75%         37.000000
# max       2013.000000
# Name: total_off_time, dtype: float64

# %%
tot_max_fail_mask = train['total_off_time'] > 374
tot_max_fail = train[tot_max_fail_mask]
tot_max_fail.fail_7.value_counts()

#when total off time is greater than 374, no devices fail
# Out:
# 0    35
# Name: fail_7, dtype: int64

# %%
print('Devices that fail')
display(ax = fail.hist(column='total_off_time', bins=120, figsize=(12,8), color='orange', zorder=2, rwidth=0.9))
# Out:
# Devices that fail

# %%
print('Devices that do not fail')
ax = nofail.hist(column='total_off_time', bins=60, figsize=(12,8), color='green', zorder=2, rwidth=0.9)
# Out:
# Devices that do not fail

# %% [markdown]
# ## Adding new columns

# %%
ser_charging_rate = train[['charging_rate_lag3', 'charging_rate_lag4', 'charging_rate_lag5',
       'charging_rate_lag6', 'charging_rate_lag7']].mean(axis=1)
ser_discharging_rate = train[['discharging_rate_lag3',
       'discharging_rate_lag4', 'discharging_rate_lag5',
       'discharging_rate_lag6', 'discharging_rate_lag7',
       'discharging_rate_lag8']].mean(axis=1)

train2['AVG_charging_rate'] = ser_charging_rate
train2['AVG_discharging_rate'] = ser_discharging_rate
train2.head()
# Out:
#           chargecycles  dischargecycles  total_off_time  number_times_restart  \
# deviceid
# 28647        50.250000        49.750000       49.000000              2.375000
# 36175        56.285714        56.000000       36.857143              1.000000
# 16107        80.380952        80.333333        2.333333              4.095238
# 27362        91.736842        91.684211       10.789474              0.736842
# 19463        71.066667        70.733333       14.266667              1.133333
#
#           avg_volt_change_charging  avg_volt_change_discharging  \
# deviceid
# 28647                   377.080000                   367.428750
# 36175                   350.517857                   350.309286
# 16107                   346.113333                   343.409524
# 27362                   356.184211                   349.844737
# 19463                   370.904000                   367.730000
#
#           avg_time_charging  avg_time_discharging  max_voltage_day  \
# deviceid
# 28647             21.696250             39.005000      4174.875000
# 36175             19.883571             32.213571      4161.000000
# 16107             13.675238             20.471429      4152.238095
# 27362             16.306842             26.189474      4164.631579
# 19463             18.797333             30.812000      4169.800000
#
#           piececount  cycle_time Date Deployed  charge_cycle_time_below_12  \
# deviceid
# 28647      14.200000   60.701250       10/6/19                       False
# 36175      19.777778   52.097143      10/27/19                       False
# 16107      19.200000   34.146667      10/31/19                       False
# 27362      23.625000   42.496316       10/1/19                       False
# 19463      12.666667   49.609333       9/13/19                        True
#
#           fail_7  AVG_charging_rate  AVG_discharging_rate
# deviceid
# 28647          0           0.044667             -1.084444
# 36175          0           0.235333              0.087778
# 16107          0          -0.276000             -0.368333
# 27362          0           0.029333             -0.923333
# 19463          0           0.025333              0.045000

# %%
train2['Date Deployed'] = pd.to_datetime(train2['Date Deployed']).dt.strftime('%Y-%m-%d')
years=[]
months=[]

for dates in train2['Date Deployed']:
    dates[1].lstrip('0')
    dates = dates.split("-")
    year = int(dates[0])
    month = int(dates[1])
    years.append(year)
    months.append(month)

train2['Year Deployed'] = years
train2['Month Deployed'] = months
train2['age_of_battery'] = (12*(2021 - train2['Year Deployed']) + 4) - train2['Month Deployed']

train2['Date Deployed'] = pd.to_datetime(train2['Date Deployed']).dt.strftime('%Y%m%d')
train2['Date Deployed'] = train2['Date Deployed'].astype(int)

# %%
# add lag 4,3,2,1 columns back
trainlag3 = train[['deviceid','avg_time_charging_lag1', 'avg_time_charging_lag2','avg_time_charging_lag3', 'avg_time_charging_lag4',
        'avg_time_discharging_lag1', 'avg_time_discharging_lag2', 'avg_time_discharging_lag3', 'avg_time_discharging_lag4',
        'charging_rate_lag3', 'discharging_rate_lag3', 'charging_rate_lag4', 'discharging_rate_lag4']].copy()
trainlag3 = trainlag3.set_index('deviceid')

pd.set_option('display.max_columns', None)
train2 = pd.concat([train2, trainlag3], axis = 1)
train2.head(7)
# Out:
#           chargecycles  dischargecycles  total_off_time  number_times_restart  \
# deviceid
# 28647        50.250000        49.750000       49.000000              2.375000
# 36175        56.285714        56.000000       36.857143              1.000000
# 16107        80.380952        80.333333        2.333333              4.095238
# 27362        91.736842        91.684211       10.789474              0.736842
# 19463        71.066667        70.733333       14.266667              1.133333
# 30054       100.900000       100.550000       10.700000              2.150000
# 26431        72.130435        71.869565       60.304348              1.956522
#
#           avg_volt_change_charging  avg_volt_change_discharging  \
# deviceid
# 28647                   377.080000                   367.428750
# 36175                   350.517857                   350.309286
# 16107                   346.113333                   343.409524
# 27362                   356.184211                   349.844737
# 19463                   370.904000                   367.730000
# 30054                   350.345500                   346.747500
# 26431                   358.789130                   353.025652
#
#           avg_time_charging  avg_time_discharging  max_voltage_day  \
# deviceid
# 28647             21.696250             39.005000      4174.875000
# 36175             19.883571             32.213571      4161.000000
# 16107             13.675238             20.471429      4152.238095
# 27362             16.306842             26.189474      4164.631579
# 19463             18.797333             30.812000      4169.800000
# 30054             12.878500             19.621000      4151.600000
# 26431             17.384783             27.495217      4170.652174
#
#           piececount  cycle_time  Date Deployed  charge_cycle_time_below_12  \
# deviceid
# 28647      14.200000   60.701250       20191006                       False
# 36175      19.777778   52.097143       20191027                       False
# 16107      19.200000   34.146667       20191031                       False
# 27362      23.625000   42.496316       20191001                       False
# 19463      12.666667   49.609333       20190913                        True
# 30054       6.375000   32.499500       20191005                       False
# 26431      20.500000   44.880000       20190913                       False
#
#           fail_7  AVG_charging_rate  AVG_discharging_rate  Year Deployed  \
# deviceid
# 28647          0           0.044667             -1.084444           2019
# 36175          0           0.235333              0.087778           2019
# 16107          0          -0.276000             -0.368333           2019
# 27362          0           0.029333             -0.923333           2019
# 19463          0           0.025333              0.045000           2019
# 30054          0          -0.000667              0.081667           2019
# 26431          0          -0.028667             -0.730000           2019
#
#           Month Deployed  age_of_battery  avg_time_charging_lag1  \
# deviceid
# 28647                 10              18                    5.12
# 36175                 10              18                   36.60
# 16107                 10              18                    5.51
# 27362                 10              18                    4.66
# 19463                  9              19                    5.10
# 30054                 10              18                   27.74
# 26431                  9              19                    4.67
#
#           avg_time_charging_lag2  avg_time_charging_lag3  \
# deviceid
# 28647                      41.11                    6.56
# 36175                       5.16                    6.23
# 16107                       5.04                    4.52
# 27362                      39.85                   35.76
# 19463                      43.24                    4.63
# 30054                       5.12                   42.39
# 26431                       5.32                   23.99
#
#           avg_time_charging_lag4  avg_time_discharging_lag1  \
# deviceid
# 28647                       4.99                       4.37
# 36175                      13.64                      62.67
# 16107                      25.01                       5.13
# 27362                       4.71                       3.93
# 19463                      40.36                       4.69
# 30054                       4.35                      45.90
# 26431                       4.76                       3.56
#
#           avg_time_discharging_lag2  avg_time_discharging_lag3  \
# deviceid
# 28647                         91.70                      15.70
# 36175                          6.53                       6.16
# 16107                          5.65                       4.14
# 27362                         76.37                      60.86
# 19463                         71.44                       3.80
# 30054                          3.99                      75.64
# 26431                          4.62                      18.57
#
#           avg_time_discharging_lag4  charging_rate_lag3  \
# deviceid
# 28647                          5.85            0.086667
# 36175                         20.37            0.136667
# 16107                         40.69           -0.460000
# 27362                          3.74            0.076667
# 19463                         82.70            0.040000
# 30054                          4.21            0.076667
# 26431                          3.46            0.270000
#
#           discharging_rate_lag3  charging_rate_lag4  discharging_rate_lag4
# deviceid
# 28647                 -1.163333           -0.070000              -0.360000
# 36175                 -0.066667            0.216667              -4.593333
# 16107                 -2.643333           -0.026667              -0.050000
# 27362                 -0.166667           -0.030000               0.013333
# 19463                  0.066667            0.016667              -0.353333
# 30054                 -0.023333            0.396667              -0.360000
# 26431                 -0.350000            0.020000              -0.026667

# %%
# fill null values of AVG_charging_rate & AVG_discharging_rate
mean_charge = train2['AVG_charging_rate'].mean()
mean_discharge = train2['AVG_discharging_rate'].mean()
train2['AVG_charging_rate'].fillna(value=mean_charge, inplace=True)    
train2['AVG_discharging_rate'].fillna(value=mean_charge, inplace=True)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40500 entries, 28647 to 20795
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   chargecycles                 40500 non-null  float64
#  1   dischargecycles              40500 non-null  float64
#  2   total_off_time               40500 non-null  float64
#  3   number_times_restart         40500 non-null  float64
#  4   avg_volt_change_charging     40500 non-null  float64
#  5   avg_volt_change_discharging  40500 non-null  float64
#  6   avg_time_charging            40500 non-null  float64
#  7   avg_time_discharging         40500 non-null  float64
#  8   max_voltage_day              40500 non-null  float64
#  9   piececount                   40500 non-null  float64
#  10  cycle_time                   40500 non-null  float64
#  11  Date Deployed                40500 non-null  int64
#  12  charge_cycle_time_below_12   40500 non-null  bool
#  13  fail_7                       40500 non-null  int64
#  14  AVG_charging_rate            40500 non-null  float64
#  15  AVG_discharging_rate         40500 non-null  float64
#  16  Year Deployed                40500 non-null  int64
#  17  Month Deployed               40500 non-null  int64
#  18  age_of_battery               40500 non-null  int64
#  19  avg_time_charging_lag1       40500 non-null  float64
#  20  avg_time_charging_lag2       40500 non-null  float64
#  21  avg_time_charging_lag3       40500 non-null  float64
#  22  avg_time_charging_lag4       40500 non-null  float64
#  23  avg_time_discharging_lag1    40500 non-null  float64
#  24  avg_time_discharging_lag2    40500 non-null  float64
#  25  avg_time_discharging_lag3    40500 non-null  float64
#  26  avg_time_discharging_lag4    40500 non-null  float64
#  27  charging_rate_lag3           40500 non-null  float64
#  28  discharging_rate_lag3        40500 non-null  float64
#  29  charging_rate_lag4           40500 non-null  float64
#  30  discharging_rate_lag4        40500 non-null  float64
# dtypes: bool(1), float64(25), int64(5)
# memory usage: 9.6 MB

# %% [markdown]
# ## More visualizations, looking for patterns in lag 3 charging rate, discharging rate

# %%
age_categories = train2['age_of_battery'].unique()
age_categories
# Out:
# array([18, 19, 17, 20, 16, 15, 14])

# %%
sns.set_palette('RdBu_r')
sns.countplot(data=train2, x='age_of_battery', hue='fail_7')

# %%
train3  = train2   #train3 is a copy of train2

train3['charging_rate_lag4'] = train3['charging_rate_lag4'].abs()
train3['discharging_rate_lag4'] = train3['discharging_rate_lag4'].abs()
train3['discharging_rate_lag3'] = train3['discharging_rate_lag3'].abs()
train3['charging_rate_lag3'] = train3['charging_rate_lag3'].abs()

# %%
custom_palette1 = ['#FF6900','#00D084']
custom_palette2 = ['#008000','#228B22']

sns.set_palette(custom_palette1)
sns.relplot(data=train3[train3["fail_7"]==1], x='charging_rate_lag4',
            y='discharging_rate_lag4', kind='scatter').set(title='Devices that fail -- charging/discharging lag4')
plt.show()

# %%
sns.relplot(data=train3[train3["fail_7"]==1], x='charging_rate_lag3', 
            y='discharging_rate_lag3', kind='scatter').set(title='Devices that fail -- charging/discharging lag3')
plt.show()

# %%
sns.set_palette(custom_palette2)
sns.relplot(data=train3[train3["fail_7"]==0], x='charging_rate_lag4', 
            y='discharging_rate_lag4', kind='scatter').set(title='Devices that do not fail -- charging/discharging lag4')
plt.show()

# %%
sns.relplot(data=train3[train3["fail_7"]==0], x='charging_rate_lag3', 
            y='discharging_rate_lag3', kind='scatter').set(title='Devices that do not fail -- charging/discharging lag3')
plt.show()

# %% [markdown]
# ### Making predictions. We will be using train2 to make predictions:

# %% [raw]
# Recap of train2:
#     - train2 is 40,500 rows, 30 columns.
#     - Includes all non-lag columns minus LastRecord
#     - Year, months extracted from date deployed
#     - Added age of battery in months
#     - Added new columns AVG_charging_rate & AVG_discharging_rate which is the mean of all 14 dis/charging rates
#     - Added back most recent lag 1,2,3,4 for avg_time_dis/charging
#             and dis/charging_rate lag 3,4
#             We added these columns in because they do not have missing values, and lag3 is a recurring feature on our models.

# %%
train2 = train2.drop(columns=['Date Deployed'])

# %%
train2.shape
# Out:
# (40500, 30)

# %%
'''
First Model- Logistic Regression, train2

'''
X_train, X_test, y_train, y_test = train_test_split(train2.drop('fail_7', axis = 1), train2['fail_7'])
logreg = linear_model.LogisticRegression(max_iter = 10000)
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm
# Out:
# array([[7689,   89],
#        [2249,   98]])

# %%
cmn
# Out:
# array([[0.98855747, 0.01144253],
#        [0.95824457, 0.04175543]])

# %%
'''
Second Logistic Regression Model - train2, scaled with MinMax

'''
#scale on all columns except for dates and response
scale_on = train2[train2.drop(columns = ['Year Deployed', 'Month Deployed', 'age_of_battery', 'fail_7']).columns]
date_cols = train2[['Year Deployed', 'Month Deployed', 'age_of_battery', 'fail_7']]
cols = scale_on.columns
ms = MinMaxScaler()

trainscale = ms.fit_transform(scale_on)
trainscale = pd.DataFrame(trainscale, columns = cols, index=train2.index)
trainscale = pd.concat([trainscale, date_cols], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(trainscale.drop('fail_7', axis = 1), trainscale['fail_7'])
logreg = linear_model.LogisticRegression(max_iter = 1000)
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm
# Out:
# array([[7722,   34],
#        [2336,   33]])

# %%
cmn
# Out:
# array([[0.9956163 , 0.0043837 ],
#        [0.98607007, 0.01392993]])

# %%
'''
Third Logistic Regression Model - train2, standardized

'''
scale_std = train2[train2.drop(columns = ['Year Deployed', 'Month Deployed', 'age_of_battery', 'fail_7']).columns]
date_cols = train2[['Year Deployed', 'Month Deployed', 'age_of_battery', 'fail_7']]
cols = scale_on.columns
scaler = StandardScaler()

trainstd = scaler.fit_transform(scale_std)
trainstd = pd.DataFrame(trainstd, columns = cols, index=train2.index)
trainstd = pd.concat([trainstd, date_cols], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(trainstd.drop('fail_7', axis = 1), trainstd['fail_7'])
logreg = linear_model.LogisticRegression(max_iter = 1000)
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm
# Out:
# array([[7712,   56],
#        [2298,   59]])

# %%
cmn
# Out:
# array([[0.99279094, 0.00720906],
#        [0.97496818, 0.02503182]])

# %%
'''
Logistic regression is not a good model 
'''
# Out:
# '\nLogistic regression is not a good model \n'

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn import tree

# %%
'''
Decision Tree on train2
'''
y = train2["fail_7"]  # Specify one column as the target variable
X = train2.drop('fail_7', axis = 1)  # Specify at least two columns as features


# Split the data into train and test subsets
# You can adjust the test size and random state
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((28350, 29), (12150, 29), (28350,), (12150,))

# %%
'''

Decison tree classification template from DataCamp:

'''
# Define a parameter grid with distributions of possible parameters to use
rs_param_grid = {
    "criterion": ["gini"],
    "max_depth": list((range(4, 12))),
    "min_samples_split": list((range(2, 5))),
    "min_samples_leaf": list((range(1, 5))),
    "ccp_alpha": [0, 0.001, 0.01, 0.1],
}

# Create a decision tree classifer object
clf = DecisionTreeClassifier(random_state=42)

# Instantiate RandomizedSearchCV() with clf and the parameter grid
clf_rs = RandomizedSearchCV(
    estimator=clf,
    param_distributions=rs_param_grid,
    cv=3,  # Number of folds
    n_iter=20,  # Number of parameter candidate settings to sample
    verbose=3,  # The higher this is, the more messages are outputed
    random_state=42,
)

# Train the model on the training set
clf_rs.fit(X_train, y_train)

# Print the best parameters and highest accuracy
print("Best parameters found: ", clf_rs.best_params_)
print("Best accuracy found: ", clf_rs.best_score_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=3;, score=0.786 total time=   1.0s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=3;, score=0.792 total time=   1.0s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=3;, score=0.793 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=3;, score=0.786 total time=   0.7s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=3;, score=0.792 total time=   0.7s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=3;, score=0.793 total time=   0.8s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.769 total time=   0.9s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.769 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.768 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4;, score=0.769 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4;, score=0.769 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4;, score=0.768 total time=   0.4s
# [CV 1/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.800 total time=   0.5s
# [CV 2/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.800 total time=   0.5s
# [CV 3/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.803 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2;, score=0.768 total time=   0.6s
# [CV 1/3] END ccp_alpha=0, criterion=gini, max_depth=6, min_samples_leaf=4, min_samples_split=2;, score=0.806 total time=   0.4s
# [CV 2/3] END ccp_alpha=0, criterion=gini, max_depth=6, min_samples_leaf=4, min_samples_split=2;, score=0.808 total time=   0.4s
# [CV 3/3] END ccp_alpha=0, criterion=gini, max_depth=6, min_samples_leaf=4, min_samples_split=2;, score=0.811 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.808 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.811 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2;, score=0.818 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2;, score=0.768 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=3;, score=0.786 total time=   0.4s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=3;, score=0.792 total time=   0.4s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=3;, score=0.793 total time=   0.4s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=2, min_samples_split=4;, score=0.786 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=2, min_samples_split=4;, score=0.792 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=2, min_samples_split=4;, score=0.793 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=3;, score=0.808 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=3;, score=0.811 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=3;, score=0.818 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=2, min_samples_split=2;, score=0.786 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=2, min_samples_split=2;, score=0.792 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=2, min_samples_split=2;, score=0.793 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.786 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.792 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.793 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=4;, score=0.808 total time=   0.3s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=4;, score=0.811 total time=   0.3s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=4;, score=0.818 total time=   0.3s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.808 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.811 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.818 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.808 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.811 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=4;, score=0.818 total time=   0.5s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.769 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.768 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.769 total time=   0.6s
# [CV 2/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.769 total time=   0.6s
# [CV 3/3] END ccp_alpha=0.1, criterion=gini, max_depth=10, min_samples_leaf=3, min_samples_split=3;, score=0.768 total time=   0.6s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=3;, score=0.786 total time=   0.5s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=3;, score=0.792 total time=   0.5s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=8, min_samples_leaf=3, min_samples_split=3;, score=0.793 total time=   0.5s
# Best parameters found:  {'min_samples_split': 2, 'min_samples_leaf': 3, 'max_depth': 5, 'criterion': 'gini', 'ccp_alpha': 0.001}
# Best accuracy found:  0.8123456790123457

# %%
# Define parameters: these will need to be tuned to prevent overfitting and underfitting
params = {
    "criterion": "gini",  # Function to measure the quality of a split: 'Gini' or 'Entropy'
    "max_depth": 5,  # Max depth of the tree
    "min_samples_split": 2,  # Min number of samples required to split a node
    "min_samples_leaf": 3,  # Min number of samples required at a leaf node
    "ccp_alpha": 0.001,  # Cost complexity parameter for pruning
    "random_state": 42,
}

# Create a DecisionTreeClassifier object with the parameters above
clf = DecisionTreeClassifier(**params)

# Train the decision tree classifer on the train set
clf = clf.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = clf.predict(X_test)

# %%
# Evaluate accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8102880658436215

# %%
cm = confusion_matrix(y_test, y_pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm
# Out:
# array([[8806,  505],
#        [1800, 1039]])

# %%
cmn
# Out:
# array([[0.94576308, 0.05423692],
#        [0.63402607, 0.36597393]])

# %%
plt.figure(figsize=(48, 24))
tree.plot_tree(clf, feature_names=X.columns, class_names = ['0','1'], filled = True, rounded = True)
# Out:
# [Text(0.375, 0.9166666666666666, 'charge_cycle_time_below_12 <= 0.5\ngini = 0.356\nsamples = 28350\nvalue = [21788, 6562]\nclass = 0'),
#  Text(0.25, 0.75, 'gini = 0.152\nsamples = 11626\nvalue = [10666, 960]\nclass = 0'),
#  Text(0.5, 0.75, 'discharging_rate_lag3 <= 0.122\ngini = 0.446\nsamples = 16724\nvalue = [11122, 5602]\nclass = 0'),
#  Text(0.25, 0.5833333333333334, 'avg_volt_change_charging <= 352.189\ngini = 0.364\nsamples = 11805\nvalue = [8980, 2825]\nclass = 0'),
#  Text(0.125, 0.4166666666666667, 'gini = 0.324\nsamples = 6541\nvalue = [5209, 1332]\nclass = 0'),
#  Text(0.375, 0.4166666666666667, 'gini = 0.406\nsamples = 5264\nvalue = [3771, 1493]\nclass = 0'),
#  Text(0.75, 0.5833333333333334, 'charging_rate_lag3 <= 0.118\ngini = 0.492\nsamples = 4919\nvalue = [2142, 2777]\nclass = 1'),
#  Text(0.625, 0.4166666666666667, 'discharging_rate_lag3 <= 0.198\ngini = 0.458\nsamples = 3953\nvalue = [1405, 2548]\nclass = 1'),
#  Text(0.5, 0.25, 'charging_rate_lag3 <= 0.045\ngini = 0.498\nsamples = 1169\nvalue = [549, 620]\nclass = 1'),
#  Text(0.375, 0.08333333333333333, 'gini = 0.468\nsamples = 786\nvalue = [293, 493]\nclass = 1'),
#  Text(0.625, 0.08333333333333333, 'gini = 0.443\nsamples = 383\nvalue = [256, 127]\nclass = 0'),
#  Text(0.75, 0.25, 'gini = 0.426\nsamples = 2784\nvalue = [856, 1928]\nclass = 1'),
#  Text(0.875, 0.4166666666666667, 'gini = 0.362\nsamples = 966\nvalue = [737, 229]\nclass = 0')]

# %%
#for row in train2['age_of_battery']:
  #print(row)

# %%
import json
test = pd.read_csv('test_for_submissions.csv')
test = pd.DataFrame(test)

fail_7 = []

for row in test.iterrows():
  if row['charge_cycle_time_below_12'] == False:
    fail_7.append(0)
  elif row['charge_cycle_time_below_12'] == True:
    if row['discharging_rate_lag3'] <= 0.122:
      fail_7.append(0)
    elif row['discharging_rate_lag3'] > 0.122:
        if row['charging_rate_lag3'] <= 0.118:
          if row['discharging_rate_lag3'] <= 0.198:
            if row['charging_rate_lag3'] <= 0.045:
              fail_7.append(1)
            elif row['charging_rate_lag3'] > 0.045:
              fail_7.append(0)
          elif row['discharging_rate_lag3'] > 0.198:
            fail_7.append(1)
        elif row['charging_rate_lag3'] > 0.118:
          fail_7.append(0)

'''
for device in test:
  if 'charge_cycle_time_below_12' = False:
    fail_7.append(0)
  elif 'charge_cycle_time_below_12' = True:
    if discharging_rate_lag3 <= 0.122:
      fail_7.append(0)
    elif discharging_rate_lag3 > 0.122:
        if charging_rate_lag3 <= 0.118:
          if discharging_rate_lag3 <= 0.198:
            if charging_rate_lag3 <= 0.045:
              fail_7.append(1)
            elif charging_rate_lag3 > 0.045:
              fail_7.append(0)
          elif discharging_rate_lag3 > 0.198:
            fail_7.append(1)
        elif charging_rate_lag3 > 0.118:
          fail_7.append(0)
'''
'''
for value in test['charge_cycle_time_below_12]:
  if value == False:
    fail_7.append('0')
  elif value == True:
    for value in test['discharging_rate_lag3']:
      if value <= 0.122:
        fail_7.append('0')
      elif value > 0.122:
        for value in test['charging_rate_lag3']:
          if value <= 0.118:
            for value in test['discharging_rate_lag3']:
              if value <= 0.198:
                for value in test['charging_rate_lag3']:
                  if value <= 0.045:
                    fail_7.append('1')
                  elif value > 0.045:
                    fail_7.append('0')
              elif value > 0.198:
                fail_7.append('1')
          elif value > 0.118:
            fail_7.append('0') '''

fail_7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-f0e395804a21> in <module>()
#       6
#       7 for row in test.iterrows():
# ----> 8   if row['charge_cycle_time_below_12'] == False:
#       9     fail_7.append(0)
#      10   elif row['charge_cycle_time_below_12'] == True:
#
# TypeError: tuple indices must be integers or slices, not str

# %%
'''
Decision Tree on standardized train2 
'''
y = trainstd["fail_7"]  # Specify one column as the target variable
X = trainstd.drop('fail_7', axis = 1)  # Specify at least two columns as features


# Split the data into train and test subsets
# You can adjust the test size and random state
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

clf = DecisionTreeClassifier(random_state=42)
clf_rs.fit(X_train, y_train)
print("Best parameters found: ", clf_rs.best_params_)
print("Best accuracy found: ", clf_rs.best_score_)

# %%
# Define parameters: these will need to be tuned to prevent overfitting and underfitting
params = {
    "criterion": "gini",  # Function to measure the quality of a split: 'Gini' or 'Entropy'
    "max_depth": 7,  # Max depth of the tree
    "min_samples_split": 4,  # Min number of samples required to split a node
    "min_samples_leaf": 3,  # Min number of samples required at a leaf node
    "ccp_alpha": 0.001,  # Cost complexity parameter for pruning
    "random_state": 42,
}

# Create a DecisionTreeClassifier object with the parameters above
clf = DecisionTreeClassifier(**params)

# Train the decision tree classifer on the train set
clf = clf.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm

# %%
cmn

# %%
plt.figure(figsize=(48, 24))
tree.plot_tree(clf, feature_names=X.columns, filled = True)

# %% [markdown]
# #### XGBoost

# %%
data_dmatrix = xgb.DMatrix(data = X, label = y)
params = {"objective": 'binary:logistic', 
          "colsample_bytree" : 0.3,
          "learning_rate" : 0.1,
            "max_depth" : 5, 
          "alpha" : 10
}

cv_results = xgb.cv(dtrain = data_dmatrix, params = params, nfold = 3,
                   num_boost_round = 50, early_stopping_rounds = 10, 
                    metrics = "rmse", seed = 123)

xg_reg = xgb.train(params = params, dtrain = data_dmatrix, num_boost_round =10 )
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [20,20]
plt.show()

# %%
'''
XGBoost on train2
'''

y = train2['fail_7']
X = train2.drop('fail_7', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 106)

xg_reg = xgb.XGBClassifier(objective ='binary:logistic', colsample_bytree = 0.8, learning_rate = 0.1,
                      max_depth = 6, alpha = 3, n_estimators= 70)
xg_reg.fit(X_train, y_train)
pred = xg_reg.predict(X_test)
cm = confusion_matrix(y_test, pred)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cmn

# %%
cmn

# %% [markdown]
# #### Trying unsupervised learning method: K Means

# %%
'''
K Means on train2 
'''
kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans = kmeans.fit(train2)
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))

# %%
'''
K Means on train2 min/max scaled
'''
kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans = kmeans.fit(trainscale)
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))

# %%
'''
K Means on train2 standardized
'''
kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans = kmeans.fit(trainstd)
labels = kmeans.labels_

# check how many of the samples were correctly labeled
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))

# %% [markdown]
# # TEST FOR SUB

# %%
test = pd.read_csv('test_for_submissions.csv')
test = pd.DataFrame(test)
test = test.drop(columns = ['LastRecord', 'Date Deployed'])
test.set_index('deviceid')
y_test = pd.Series(dtype = 'int')

# %%
test.info()

# %%
temp_var = int()
fail_7 = []

# %%
params = {
    "criterion": "entropy",  # Function to measure the quality of a split: 'Gini' or 'Entropy'
    "max_depth": 10,  # Max depth of the tree
    "min_samples_split": 3,  # Min number of samples required to split a node
    "min_samples_leaf": 3,  # Min number of samples required at a leaf node
    "ccp_alpha": 0.001,  # Cost complexity parameter for pruning
    "random_state": 42,
}

# Create a DecisionTreeClassifier object with the parameters above
clf = DecisionTreeClassifier(**params)
clf = clf.fit(test, y_train)

# Predict the outcomes on the test set
test_pred = clf.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-2e1ca43dede4> in <module>
#      10 # Create a DecisionTreeClassifier object with the parameters above
#      11 clf = DecisionTreeClassifier(**params)
# ---> 12 clf = clf.fit(test, y_train)
#      13
#      14 # Predict the outcomes on the test set
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
#     158                                                             check_y_params))
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     428                 # :(
#     429                 check_X_params, check_y_params = validate_separately
# --> 430                 X = check_array(X, **check_X_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
