# %%
import numpy as np 
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

from sklearn.cluster import KMeans
import xgboost as xgb

train = pd.read_csv('train_updated.csv')
train = pd.DataFrame(train)


test = pd.read_csv('test_for_submissions.csv')
test = pd.DataFrame(test)

# %%
train2 =  train[['deviceid', 'chargecycles', 'dischargecycles', 'total_off_time',
       'number_times_restart', 'avg_volt_change_charging',
       'avg_volt_change_discharging', 'avg_time_charging',
       'avg_time_discharging', 'max_voltage_day', 'piececount', 'cycle_time',
       'charge_cycle_time_below_12', 'avg_time_charging_lag1', 'avg_time_charging_lag2',
       'avg_time_charging_lag3', 'avg_time_charging_lag4',
       'avg_time_discharging_lag1', 'avg_time_discharging_lag2',
       'avg_time_discharging_lag3', 'avg_time_discharging_lag4',
       'charging_rate_lag3', 'discharging_rate_lag3', 'charging_rate_lag4',
       'discharging_rate_lag4','fail_7']].copy()

test2 = test[['deviceid', 'chargecycles', 'dischargecycles', 'total_off_time',
       'number_times_restart', 'avg_volt_change_charging',
       'avg_volt_change_discharging', 'avg_time_charging',
       'avg_time_discharging', 'max_voltage_day', 'piececount', 'cycle_time',
       'charge_cycle_time_below_12', 'avg_time_charging_lag1', 'avg_time_charging_lag2',
       'avg_time_charging_lag3', 'avg_time_charging_lag4',
       'avg_time_discharging_lag1', 'avg_time_discharging_lag2',
       'avg_time_discharging_lag3', 'avg_time_discharging_lag4',
       'charging_rate_lag3', 'discharging_rate_lag3', 'charging_rate_lag4',
       'discharging_rate_lag4']].copy()

train2 = train2.set_index('deviceid') 
test2 = test2.set_index('deviceid')

# %%
y = train2["fail_7"]  # Specify one column as the target variable
X = train2.drop('fail_7', axis = 1)  # Specify at least two columns as features


# Split the data into train and test subsets
# You can adjust the test size and random state
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=123
)

# %%
rs_param_grid = {
    "criterion": ["gini", "entropy"],
    "max_depth": list((range(4, 12))),
    "min_samples_split": list((range(2, 5))),
    "min_samples_leaf": list((range(1, 5))),
    "ccp_alpha": [0, 0.001, 0.01, 0.1],
}

# Create a decision tree classifer object
clf = DecisionTreeClassifier(random_state=123)

# Instantiate RandomizedSearchCV() with clf and the parameter grid
clf_rs = RandomizedSearchCV(
    estimator=clf,
    param_distributions=rs_param_grid,
    cv=3,  # Number of folds
    n_iter=20,  # Number of parameter candidate settings to sample
    verbose=3,  # The higher this is, the more messages are outputed
    random_state=122,
)

# Train the model on the training set
clf_rs.fit(X_train, y_train)

# Print the best parameters and highest accuracy
print("Best parameters found: ", clf_rs.best_params_)
print("Best accuracy found: ", clf_rs.best_score_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=7, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=4, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV 1/3] END ccp_alpha=0, criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 2/3] END ccp_alpha=0, criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 3/3] END ccp_alpha=0, criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=2; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.01, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.01, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.01, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.1, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 2/3] END ccp_alpha=0.1, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 3/3] END ccp_alpha=0.1, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.2s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.2s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.2s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 1/3] END ccp_alpha=0, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 2/3] END ccp_alpha=0, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 3/3] END ccp_alpha=0, criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.1, criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 2/3] END ccp_alpha=0.1, criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 3/3] END ccp_alpha=0.1, criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=3; total time=   0.2s
# [CV 1/3] END ccp_alpha=0, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=3; total time=   0.3s
# [CV 2/3] END ccp_alpha=0, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=3; total time=   0.3s
# [CV 3/3] END ccp_alpha=0, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=3; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.01, criterion=gini, max_depth=6, min_samples_leaf=3, min_samples_split=4; total time=   0.1s
# [CV 1/3] END ccp_alpha=0, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 2/3] END ccp_alpha=0, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 3/3] END ccp_alpha=0, criterion=gini, max_depth=11, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.1, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 2/3] END ccp_alpha=0.1, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 3/3] END ccp_alpha=0.1, criterion=entropy, max_depth=4, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV 1/3] END ccp_alpha=0.001, criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 2/3] END ccp_alpha=0.001, criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 3/3] END ccp_alpha=0.001, criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=3; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.001, criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=4; total time=   0.2s
# [CV 2/3] END ccp_alpha=0.001, criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=4; total time=   0.2s
# [CV 3/3] END ccp_alpha=0.001, criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=4; total time=   0.2s
# [CV 1/3] END ccp_alpha=0.01, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=3; total time=   0.3s
# [CV 2/3] END ccp_alpha=0.01, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=3; total time=   0.3s
# [CV 3/3] END ccp_alpha=0.01, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=3; total time=   0.3s
# [CV 1/3] END ccp_alpha=0.001, criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.3s
# [CV 2/3] END ccp_alpha=0.001, criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.3s
# [CV 3/3] END ccp_alpha=0.001, criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.3s
# [CV 1/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV 2/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# [CV 3/3] END ccp_alpha=0, criterion=gini, max_depth=8, min_samples_leaf=4, min_samples_split=2; total time=   0.2s
# Best parameters found:  {'min_samples_split': 4, 'min_samples_leaf': 3, 'max_depth': 7, 'criterion': 'gini', 'ccp_alpha': 0.001}
# Best accuracy found:  0.8090652557319223

# %%
# Define parameters: these will need to be tuned to prevent overfitting and underfitting
params = {
    "criterion": "entropy",  # Function to measure the quality of a split: 'Gini' or 'Entropy'
    "max_depth": 10,  # Max depth of the tree
    "min_samples_split": 3,  # Min number of samples required to split a node
    "min_samples_leaf": 3,  # Min number of samples required at a leaf node
    "ccp_alpha": 0.001,  # Cost complexity parameter for pruning
    "random_state": 123,
}

# Create a DecisionTreeClassifier object with the parameters above
clf = DecisionTreeClassifier(**params)

# Train the decision tree classifer on the train set
clf = clf.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = clf.predict(X_test)

# %%
test_pred = clf.predict(test2)

# %%
test_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
test2['fail_7'] = test_pred

# %%
test2.iloc[ : , 24:]
# Out:
#           fail_7
# deviceid
# 42979          1
# 14911          0
# 48386          0
# 18822          0
# 49810          0
# ...          ...
# 23329          0
# 35263          0
# 12544          0
# 44502          1
# 16821          0
#
# [4500 rows x 1 columns]

# %%
test2.fail_7.value_counts(normalize = True)
# Out:
# 0    0.859556
# 1    0.140444
# Name: fail_7, dtype: float64

# %%
plt.figure(figsize=(48, 24))
tree.plot_tree(clf, feature_names=X.columns, filled = True)
# Out:
# [Text(1161.9529411764706, 1211.4514285714286, 'charge_cycle_time_below_12 <= 0.5\nentropy = 0.784\nsamples = 28350\nvalue = [21732, 6618]'),
#  Text(472.6588235294118, 1025.074285714286, 'discharging_rate_lag3 <= 0.435\nentropy = 0.428\nsamples = 11593\nvalue = [10578, 1015]'),
#  Text(315.1058823529412, 838.6971428571429, 'number_times_restart <= 1.811\nentropy = 0.378\nsamples = 8386\nvalue = [7772, 614]'),
#  Text(157.5529411764706, 652.32, 'entropy = 0.322\nsamples = 5228\nvalue = [4921, 307]'),
#  Text(472.6588235294118, 652.32, 'entropy = 0.46\nsamples = 3158\nvalue = [2851, 307]'),
#  Text(630.2117647058824, 838.6971428571429, 'entropy = 0.544\nsamples = 3207\nvalue = [2806, 401]'),
#  Text(1851.2470588235294, 1025.074285714286, 'discharging_rate_lag3 <= 0.145\nentropy = 0.919\nsamples = 16757\nvalue = [11154, 5603]'),
#  Text(1339.2, 838.6971428571429, 'discharging_rate_lag3 <= -0.135\nentropy = 0.872\nsamples = 14592\nvalue = [10323, 4269]'),
#  Text(787.7647058823529, 652.32, 'charging_rate_lag3 <= -0.202\nentropy = 0.996\nsamples = 2417\nvalue = [1117, 1300]'),
#  Text(630.2117647058824, 465.9428571428572, 'entropy = 0.618\nsamples = 365\nvalue = [309, 56]'),
#  Text(945.3176470588236, 465.9428571428572, 'charging_rate_lag3 <= 0.045\nentropy = 0.967\nsamples = 2052\nvalue = [808, 1244]'),
#  Text(787.7647058823529, 279.5657142857142, 'entropy = 0.91\nsamples = 1781\nvalue = [579, 1202]'),
#  Text(1102.8705882352942, 279.5657142857142, 'entropy = 0.622\nsamples = 271\nvalue = [229, 42]'),
#  Text(1890.6352941176472, 652.32, 'avg_volt_change_discharging <= 347.736\nentropy = 0.801\nsamples = 12175\nvalue = [9206, 2969]'),
#  Text(1575.5294117647059, 465.9428571428572, 'charging_rate_lag3 <= -0.025\nentropy = 0.728\nsamples = 6100\nvalue = [4860, 1240]'),
#  Text(1417.9764705882353, 279.5657142857142, 'entropy = 0.598\nsamples = 1299\nvalue = [1110, 189]'),
#  Text(1733.0823529411766, 279.5657142857142, 'discharging_rate_lag3 <= 0.065\nentropy = 0.758\nsamples = 4801\nvalue = [3750, 1051]'),
#  Text(1575.5294117647059, 93.18857142857155, 'entropy = 0.74\nsamples = 4585\nvalue = [3625, 960]'),
#  Text(1890.6352941176472, 93.18857142857155, 'entropy = 0.982\nsamples = 216\nvalue = [125, 91]'),
#  Text(2205.7411764705885, 465.9428571428572, 'discharging_rate_lag3 <= 0.095\nentropy = 0.862\nsamples = 6075\nvalue = [4346, 1729]'),
#  Text(2048.188235294118, 279.5657142857142, 'entropy = 0.85\nsamples = 5766\nvalue = [4174, 1592]'),
#  Text(2363.294117647059, 279.5657142857142, 'charging_rate_lag3 <= -0.032\nentropy = 0.991\nsamples = 309\nvalue = [172, 137]'),
#  Text(2205.7411764705885, 93.18857142857155, 'entropy = 0.621\nsamples = 97\nvalue = [82, 15]'),
#  Text(2520.8470588235296, 93.18857142857155, 'entropy = 0.984\nsamples = 212\nvalue = [90, 122]'),
#  Text(2363.294117647059, 838.6971428571429, 'charging_rate_lag3 <= -0.085\nentropy = 0.961\nsamples = 2165\nvalue = [831, 1334]'),
#  Text(2205.7411764705885, 652.32, 'entropy = 0.621\nsamples = 162\nvalue = [137, 25]'),
#  Text(2520.8470588235296, 652.32, 'entropy = 0.931\nsamples = 2003\nvalue = [694, 1309]')]
